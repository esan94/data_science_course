# %% [markdown]
# # Ejercicios

# %% [markdown]
# **Ejercicio 23**: Crea una función que imprima el doble de un número que se da como parámetro.

# %% [markdown]
# **Ejercicio 24**: Crea una función que devuelva la suma de dos números, siendo ambos parámetros. Desde fuera de la función, llámala e imprime los resultados con números de prueba.

# %% [markdown]
# **Ejercicio 25**: Implementaremos un sistema de control de almacenes. Para ello, crearemos las siguientes funciones:
#
# 1. Crear un almacén vacío.
# 2. Añadir un objeto nuevo al almacén (a continuación del último).
# 3. Mostrar por pantalla un objeto dado.
# 4. Mostrar por pantalla todos los objetos del almacén.
# 5. Eliminar un objeto del almacén dada su posición. Si la posición no es válida (si no existe un objeto en esa posición), no hará nada.
# 6. Devolver un objeto del almacén dada su posición. Si la posición no es válida (si no existe un objeto en esa posición), devolverá la cadena "nada" .
#
#
# Además, habrá un programa principal que realice los siguiente pasos:
# Crear los objetos "plancha" , "cafetera" , "mesa" y "silla" en ese orden. Buscar el objeto en la posición 10. Si no existe, se imprimirá "No existe el objecto con posición 10." .
# Eliminar el objeto en la posición 2.
# Imprimir el contenido actual del almacén.

# %% [markdown]
# **Ejercicio 26**: Crea un programa que escriba los números del 1 al 10, línea por línea, en un archivo de texto.

# %% [markdown]
# **Ejercicio 27**: Escribe una función que cargue los números anteriores de datos.dat . Después, escribe una función que, para cada número,
# calcule la suma de todos los números desde el 0 hasta ese número

# %% [markdown]
# **Ejercicio 28**: Como ejercicio de ficheros vamos a hacer un sistema de control de alta de clientes. Básicamente, las funciones implementadas tienen que poder hacer que este código se ejecute y muestre la lista de clientes:
#
# ```python
# clientes = pedirinformacion()
# guardarlista(clientes, "clientes.txt")
# clientescargados = cargarlista("clientes.txt")
# mostrarclientes(clientescargados)
#
# ```
#
# Ésta sería la ejecución que se espera:
#
# Nombre del cliente ("fin" para terminar): francisco
#
# Nombre del cliente ("fin" para terminar): fin
#
# Lista de clientes:
#
# Cliente [francisco]
#
#
# 1. pedirinformacion() pide, en un bucle, la información hasta que se escribe "fin".
#
# 2. guardarlista guarda los clientes como texto, cada cliente con una línea.
# 3. cargarlista crea una lista de clientes vacía (cosa que debe hacerse desde una función que ha de ser llamada desde cargarlista ), la rellena con lo que haya en el archivo (que hay, en cada línea, un cliente), y devuelve esa lista rellena con un return .
# 4. mostrarclientes recorre la lista de clientes y, por cada cliente, llama a una función extra llamada mostrarcliente que muestra un cliente.

# %% [markdown]
# **Ejercicio 29**:

# %%
from IPython.display import Image 
Image(filename='data/ejercicio_clases.png')

# %% [markdown]
# **Ejercicio 30**: Escribe una función que chequee si una palabra es un palíndromo o no.
